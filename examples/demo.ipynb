# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../')

import sodgen
from sodgen import *

import matplotlib.pyplot as plt

# %%
num = 16

# %%
cfg = config.Config()
cfg.lang = 'zh-CN'
cfg.fonts_dir = './fonts_dir'

# %%
ims = gen.generate(num, config=cfg)

# %%
plt.figure(figsize=(20, 20))

for i in range(1, num + 1):
    plt.subplot(4, 4, i)
    plt.imshow(ims[i - 1].image)
